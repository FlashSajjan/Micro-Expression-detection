# %%
import os
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, add, concatenate
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
base_dataset_path = "E:/FacialMicroExpression/data"
excel_file_path = "Section A.xls"

# %%
# 1) Build a normalized lookup (label_map) from your Excel “Filename” → “Emotion”
def load_label_map(excel_path):
    df = pd.read_excel(excel_path)
    # Make sure columns are lowercase and stripped
    df.columns = [c.strip().lower() for c in df.columns]

    label_map = {}
    for _, row in df.iterrows():
        raw_name = str(row['filename']).strip().lower()
        # Normalize by removing underscores, hyphens, non‐alphanumeric
        key = ''.join(ch for ch in raw_name if ch.isalnum())
        label_map[key] = row['emotion'].strip().lower()
    return label_map

# 2) Given an EP‐folder name (e.g. "EP01_12"), normalize the same way
def normalize_folder_name(folder_name):
    lower = folder_name.strip().lower()
    return ''.join(ch for ch in lower if ch.isalnum())

# 3) Load all _images_ from CASME I, but use the EP‐folder (parent) to get the label
def load_casme_images(base_dir, label_map, output_size=(112, 112)):
    X, y = [], []
    for subject_folder in os.listdir(base_dir):
        subject_path = os.path.join(base_dir, subject_folder)
        if not os.path.isdir(subject_path):
            continue  # skip anything that isn’t a directory

        # e.g. subject_folder might be "S1" or "sub01"
        for ep_folder in os.listdir(subject_path):
            ep_path = os.path.join(subject_path, ep_folder)
            if not os.path.isdir(ep_path):
                continue  # skip if it isn’t a folder

            # Normalize the EP‐folder name exactly as we did in load_label_map
            ep_key = normalize_folder_name(ep_folder)
            label = label_map.get(ep_key, None)
            if label is None:
                print(f"WARNING: No Excel label found for EP‐folder '{ep_folder}' → key='{ep_key}'")
                # Skip entire folder if we can’t find a label
                continue

            # Now iterate inside ep_path, but only pick image files
            for fname in os.listdir(ep_path):
                ext = fname.lower().split('.')[-1]
                if ext not in ('jpg', 'jpeg', 'png'):
                    # skip .log, .txt, or any non‐image file
                    continue

                full_img_path = os.path.join(ep_path, fname)
                img = cv2.imread(full_img_path)
                if img is None:
                    # occasionally cv2.imread fails if file is corrupted
                    continue

                # 3a) Face detection (crop to face) ⬇️
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                faces = face_cascade.detectMultiScale(
                    gray,
                    scaleFactor=1.1,
                    minNeighbors=4,
                    minSize=(48, 48)
                )
                if len(faces) > 0:
                    x, y0, w, h = faces[0]
                    face_roi = img[y0 : y0 + h, x : x + w]
                else:
                    # fallback to entire frame if no face detected
                    face_roi = img

                # 3b) Resize & CLAHE to handle lighting ⬇️
                face_resized = cv2.resize(face_roi, output_size)

                # Convert to LAB → apply CLAHE on L channel → convert back
                lab = cv2.cvtColor(face_resized, cv2.COLOR_BGR2LAB)
                l, a, b = cv2.split(lab)
                clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
                l_eq = clahe.apply(l)
                lab_eq = cv2.merge((l_eq, a, b))
                face_eq = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

                X.append(face_eq)
                y.append(label)

    return X, y


# 4) (OPTIONAL) If you also have videos (.avi) under subject folders,
#    use the same EP‐folder lookup approach instead of per‐frame.
def load_casme_videos(base_dir, label_map, output_size=(112,112)):
    Xv, yv = [], []
    for subject_folder in os.listdir(base_dir):
        subject_path = os.path.join(base_dir, subject_folder)
        if not os.path.isdir(subject_path):
            continue

        for fname in os.listdir(subject_path):
            if not fname.lower().endswith('.avi'):
                continue
            full_video_path = os.path.join(subject_path, fname)

            # Normalize the video’s “EP‐name” from its filename:
            # e.g. "EP14_8.avi" → strip extension → "ep14_8" → normalize → "ep148"
            # But the actual EP‐folder might be "EP14_8", so EP14_8 is the key.
            raw_base = os.path.splitext(fname)[0]  # e.g. "EP14_8"
            ep_key = normalize_folder_name(raw_base)
            label = label_map.get(ep_key, None)
            if label is None:
                print(f"WARNING: No Excel label for video '{fname}' → key='{ep_key}'")
                continue

            cap = cv2.VideoCapture(full_video_path)
            frames = []
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break

                # 4a) Face‐crop each frame
                gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
                faces = face_cascade.detectMultiScale(
                    gray,
                    scaleFactor=1.1,
                    minNeighbors=4,
                    minSize=(48,48)
                )
                if len(faces) > 0:
                    x, y0, w, h = faces[0]
                    face_roi = frame[y0 : y0+h, x : x+w]
                else:
                    face_roi = frame

                # 4b) Resize & CLAHE
                face_resized = cv2.resize(face_roi, output_size)
                lab = cv2.cvtColor(face_resized, cv2.COLOR_BGR2LAB)
                l, a, b = cv2.split(lab)
                clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
                l_eq = clahe.apply(l)
                lab_eq = cv2.merge((l_eq, a, b))
                face_eq = cv2.cvtColor(lab_eq, cv2.COLOR_LAB2BGR)

                frames.append(face_eq)

            cap.release()

            if len(frames) > 0:
                # e.g. average frames to one “dynamic image” (or choose another method)
                dyn = np.mean(np.stack(frames, axis=0), axis=0).astype(np.uint8)
                Xv.append(dyn)
                yv.append(label)

    return Xv, yv

# %%
def preprocess_and_split(X, y):
    X_np = np.array(X, dtype='float32') / 255.0
    le = LabelEncoder()
    y_enc = le.fit_transform(y)             # e.g. “happy”→0, “surprise”→1, …
    y_onehot = to_categorical(y_enc)
    X_train, X_test, y_train, y_test = train_test_split(
        X_np, y_onehot, test_size=0.2, random_state=42, stratify=y_enc
    )
    return X_train, X_test, y_train, y_test, le

# %%
for root, _, files in os.walk(base_dataset_path):
    for f in files:
        base = os.path.splitext(f)[0].lower()
        key = ''.join(ch for ch in base if ch.isalnum())
        if key not in label_map:
            print("UNMATCHED:", f, "→", key)
# Out:
# UNMATCHED: EP14_8.avi → ep148
# UNMATCHED: hs_err_pid8508.log → hserrpid8508
# UNMATCHED: EP01_12-1.jpg → ep01121
# UNMATCHED: EP01_12-10.jpg → ep011210
# UNMATCHED: EP01_12-100.jpg → ep0112100
# UNMATCHED: EP01_12-101.jpg → ep0112101
# UNMATCHED: EP01_12-102.jpg → ep0112102
# UNMATCHED: EP01_12-103.jpg → ep0112103
# UNMATCHED: EP01_12-104.jpg → ep0112104
# UNMATCHED: EP01_12-105.jpg → ep0112105
# UNMATCHED: EP01_12-106.jpg → ep0112106
# UNMATCHED: EP01_12-107.jpg → ep0112107
# UNMATCHED: EP01_12-108.jpg → ep0112108
# UNMATCHED: EP01_12-109.jpg → ep0112109
# UNMATCHED: EP01_12-11.jpg → ep011211
# UNMATCHED: EP01_12-110.jpg → ep0112110
# UNMATCHED: EP01_12-111.jpg → ep0112111
# UNMATCHED: EP01_12-112.jpg → ep0112112
# UNMATCHED: EP01_12-98.jpg → ep011298
# UNMATCHED: EP01_12-99.jpg → ep011299
# UNMATCHED: EP01_5-1.jpg → ep0151
# UNMATCHED: EP01_5-10.jpg → ep01510
# UNMATCHED: EP01_5-100.jpg → ep015100
# UNMATCHED: EP01_5-101.jpg → ep015101
# UNMATCHED: EP01_5-102.jpg → ep015102
# UNMATCHED: EP01_5-103.jpg → ep015103
# UNMATCHED: EP01_5-104.jpg → ep015104
# UNMATCHED: EP01_5-105.jpg → ep015105
# UNMATCHED: EP01_5-106.jpg → ep015106
# UNMATCHED: EP01_5-107.jpg → ep015107
# UNMATCHED: EP01_5-108.jpg → ep015108
# UNMATCHED: EP01_5-109.jpg → ep015109
# UNMATCHED: EP01_5-11.jpg → ep01511
# UNMATCHED: EP01_5-110.jpg → ep015110
# UNMATCHED: EP01_5-111.jpg → ep015111
# UNMATCHED: EP01_5-112.jpg → ep015112
# UNMATCHED: EP01_5-113.jpg → ep015113
# UNMATCHED: EP01_5-114.jpg → ep015114
# UNMATCHED: EP01_5-115.jpg → ep015115
# UNMATCHED: EP01_5-116.jpg → ep015116
# UNMATCHED: EP01_5-117.jpg → ep015117
# UNMATCHED: EP01_5-118.jpg → ep015118
# UNMATCHED: EP01_5-119.jpg → ep015119
# UNMATCHED: EP01_5-12.jpg → ep01512
# UNMATCHED: EP01_5-120.jpg → ep015120
# UNMATCHED: EP01_5-121.jpg → ep015121
# UNMATCHED: EP01_5-122.jpg → ep015122
# UNMATCHED: EP01_5-123.jpg → ep015123
# UNMATCHED: EP01_5-124.jpg → ep015124
# UNMATCHED: EP01_5-125.jpg → ep015125
# UNMATCHED: EP01_5-126.jpg → ep015126
# UNMATCHED: EP01_5-127.jpg → ep015127
# UNMATCHED: EP01_5-128.jpg → ep015128
# UNMATCHED: EP01_5-129.jpg → ep015129
# UNMATCHED: EP01_5-13.jpg → ep01513
# UNMATCHED: EP01_5-130.jpg → ep015130
# UNMATCHED: EP01_5-131.jpg → ep015131
# UNMATCHED: EP01_5-132.jpg → ep015132
# UNMATCHED: EP01_5-133.jpg → ep015133
# UNMATCHED: EP01_5-134.jpg → ep015134
# UNMATCHED: EP01_5-135.jpg → ep015135
# UNMATCHED: EP01_5-136.jpg → ep015136
# UNMATCHED: EP01_5-137.jpg → ep015137
# UNMATCHED: EP01_5-138.jpg → ep015138
# UNMATCHED: EP01_5-139.jpg → ep015139
# UNMATCHED: EP01_5-14.jpg → ep01514
# UNMATCHED: EP01_5-140.jpg → ep015140
# UNMATCHED: EP01_5-141.jpg → ep015141
# UNMATCHED: EP01_5-142.jpg → ep015142
# UNMATCHED: EP01_5-143.jpg → ep015143
# UNMATCHED: EP01_5-144.jpg → ep015144
# UNMATCHED: EP01_5-145.jpg → ep015145
# UNMATCHED: EP01_5-146.jpg → ep015146
# UNMATCHED: EP01_5-147.jpg → ep015147
# UNMATCHED: EP01_5-148.jpg → ep015148
# UNMATCHED: EP01_5-149.jpg → ep015149
# UNMATCHED: EP01_5-15.jpg → ep01515
# UNMATCHED: EP01_5-150.jpg → ep015150
# UNMATCHED: EP01_5-151.jpg → ep015151
# UNMATCHED: EP01_5-152.jpg → ep015152
# UNMATCHED: EP01_5-153.jpg → ep015153
# UNMATCHED: EP01_5-154.jpg → ep015154
# UNMATCHED: EP01_5-155.jpg → ep015155
# UNMATCHED: EP01_5-156.jpg → ep015156
# UNMATCHED: EP01_5-157.jpg → ep015157
# UNMATCHED: EP01_5-158.jpg → ep015158
# UNMATCHED: EP01_5-159.jpg → ep015159
# UNMATCHED: EP01_5-16.jpg → ep01516
# UNMATCHED: EP01_5-160.jpg → ep015160
# UNMATCHED: EP01_5-161.jpg → ep015161
# UNMATCHED: EP01_5-162.jpg → ep015162
# UNMATCHED: EP01_5-163.jpg → ep015163
# UNMATCHED: EP01_5-164.jpg → ep015164
# UNMATCHED: EP01_5-165.jpg → ep015165
# UNMATCHED: EP01_5-166.jpg → ep015166
# UNMATCHED: EP01_5-167.jpg → ep015167
# UNMATCHED: EP01_5-168.jpg → ep015168
# UNMATCHED: EP01_5-169.jpg → ep015169
# UNMATCHED: EP01_5-17.jpg → ep01517
# UNMATCHED: EP01_5-170.jpg → ep015170
# UNMATCHED: EP01_5-171.jpg → ep015171
# UNMATCHED: EP01_5-172.jpg → ep015172
# UNMATCHED: EP01_5-173.jpg → ep015173
# UNMATCHED: EP01_5-174.jpg → ep015174
# UNMATCHED: EP01_5-175.jpg → ep015175
# UNMATCHED: EP01_5-176.jpg → ep015176
# UNMATCHED: EP01_5-177.jpg → ep015177
# UNMATCHED: EP01_5-178.jpg → ep015178
# UNMATCHED: EP01_5-179.jpg → ep015179
# UNMATCHED: EP01_5-18.jpg → ep01518
# UNMATCHED: EP01_5-180.jpg → ep015180
# UNMATCHED: EP01_5-181.jpg → ep015181
# UNMATCHED: EP01_5-182.jpg → ep015182
# UNMATCHED: EP01_5-183.jpg → ep015183
# UNMATCHED: EP01_5-184.jpg → ep015184
# UNMATCHED: EP01_5-185.jpg → ep015185
# UNMATCHED: EP01_5-186.jpg → ep015186
# UNMATCHED: EP01_5-187.jpg → ep015187
# UNMATCHED: EP01_5-188.jpg → ep015188
# UNMATCHED: EP01_5-189.jpg → ep015189
# UNMATCHED: EP01_5-19.jpg → ep01519
# UNMATCHED: EP01_5-190.jpg → ep015190
# UNMATCHED: EP01_5-191.jpg → ep015191
# UNMATCHED: EP01_5-192.jpg → ep015192
# UNMATCHED: EP01_5-193.jpg → ep015193
# UNMATCHED: EP01_5-194.jpg → ep015194
# UNMATCHED: EP01_5-195.jpg → ep015195
# UNMATCHED: EP01_5-196.jpg → ep015196
# UNMATCHED: EP01_5-197.jpg → ep015197
# UNMATCHED: EP01_5-198.jpg → ep015198
# UNMATCHED: EP01_5-199.jpg → ep015199
# UNMATCHED: EP01_5-2.jpg → ep0152
# UNMATCHED: EP01_5-20.jpg → ep01520
# UNMATCHED: EP01_5-200.jpg → ep015200
# UNMATCHED: EP01_5-201.jpg → ep015201
# UNMATCHED: EP01_5-202.jpg → ep015202
# UNMATCHED: EP01_5-203.jpg → ep015203
# UNMATCHED: EP01_5-204.jpg → ep015204
# UNMATCHED: EP01_5-205.jpg → ep015205
# UNMATCHED: EP01_5-206.jpg → ep015206
# UNMATCHED: EP01_5-207.jpg → ep015207
# UNMATCHED: EP01_5-208.jpg → ep015208
# UNMATCHED: EP01_5-209.jpg → ep015209
# UNMATCHED: EP01_5-21.jpg → ep01521
# UNMATCHED: EP01_5-210.jpg → ep015210
# UNMATCHED: EP01_5-211.jpg → ep015211
# UNMATCHED: EP01_5-212.jpg → ep015212
# UNMATCHED: EP01_5-213.jpg → ep015213
# UNMATCHED: EP01_5-214.jpg → ep015214
# UNMATCHED: EP01_5-215.jpg → ep015215
# UNMATCHED: EP01_5-216.jpg → ep015216
# UNMATCHED: EP01_5-217.jpg → ep015217
# UNMATCHED: EP01_5-218.jpg → ep015218
# UNMATCHED: EP01_5-219.jpg → ep015219
# UNMATCHED: EP01_5-22.jpg → ep01522
# UNMATCHED: EP01_5-220.jpg → ep015220
# UNMATCHED: EP01_5-221.jpg → ep015221
# UNMATCHED: EP01_5-222.jpg → ep015222
# UNMATCHED: EP01_5-23.jpg → ep01523
# UNMATCHED: EP01_5-24.jpg → ep01524
# UNMATCHED: EP01_5-25.jpg → ep01525
# UNMATCHED: EP01_5-26.jpg → ep01526
# UNMATCHED: EP01_5-27.jpg → ep01527
# UNMATCHED: EP01_5-28.jpg → ep01528
# UNMATCHED: EP01_5-29.jpg → ep01529
# UNMATCHED: EP01_5-3.jpg → ep0153
# UNMATCHED: EP01_5-30.jpg → ep01530
# UNMATCHED: EP01_5-31.jpg → ep01531
# UNMATCHED: EP01_5-32.jpg → ep01532
# UNMATCHED: EP01_5-33.jpg → ep01533
# UNMATCHED: EP01_5-34.jpg → ep01534
# UNMATCHED: EP01_5-35.jpg → ep01535
# UNMATCHED: EP01_5-36.jpg → ep01536
# UNMATCHED: EP01_5-37.jpg → ep01537
# UNMATCHED: EP01_5-38.jpg → ep01538
# UNMATCHED: EP01_5-39.jpg → ep01539
# UNMATCHED: EP01_5-4.jpg → ep0154
# UNMATCHED: EP01_5-40.jpg → ep01540
# UNMATCHED: EP01_5-41.jpg → ep01541
# UNMATCHED: EP01_5-42.jpg → ep01542
# UNMATCHED: EP01_5-43.jpg → ep01543
# UNMATCHED: EP01_5-44.jpg → ep01544
# UNMATCHED: EP01_5-45.jpg → ep01545
# UNMATCHED: EP01_5-46.jpg → ep01546
# UNMATCHED: EP01_5-47.jpg → ep01547
# UNMATCHED: EP01_5-48.jpg → ep01548
# UNMATCHED: EP01_5-49.jpg → ep01549
# UNMATCHED: EP01_5-5.jpg → ep0155
# UNMATCHED: EP01_5-50.jpg → ep01550
# UNMATCHED: EP01_5-51.jpg → ep01551
# UNMATCHED: EP01_5-52.jpg → ep01552
# UNMATCHED: EP01_5-53.jpg → ep01553
# UNMATCHED: EP01_5-54.jpg → ep01554
# UNMATCHED: EP01_5-55.jpg → ep01555
# UNMATCHED: EP01_5-56.jpg → ep01556
# UNMATCHED: EP01_5-57.jpg → ep01557
# UNMATCHED: EP01_5-58.jpg → ep01558
# UNMATCHED: EP01_5-59.jpg → ep01559
# UNMATCHED: EP01_5-6.jpg → ep0156
# UNMATCHED: EP01_5-60.jpg → ep01560
# UNMATCHED: EP01_5-61.jpg → ep01561
# UNMATCHED: EP01_5-62.jpg → ep01562
# UNMATCHED: EP01_5-63.jpg → ep01563
# UNMATCHED: EP01_5-64.jpg → ep01564
# UNMATCHED: EP01_5-65.jpg → ep01565
# UNMATCHED: EP01_5-66.jpg → ep01566
# UNMATCHED: EP01_5-67.jpg → ep01567
# UNMATCHED: EP01_5-68.jpg → ep01568
# UNMATCHED: EP01_5-69.jpg → ep01569
# UNMATCHED: EP01_5-7.jpg → ep0157
# UNMATCHED: EP01_5-70.jpg → ep01570
# UNMATCHED: EP01_5-71.jpg → ep01571
# UNMATCHED: EP01_5-72.jpg → ep01572
# UNMATCHED: EP01_5-73.jpg → ep01573
# UNMATCHED: EP01_5-74.jpg → ep01574
# UNMATCHED: EP01_5-75.jpg → ep01575
# UNMATCHED: EP01_5-76.jpg → ep01576
# UNMATCHED: EP01_5-77.jpg → ep01577
# UNMATCHED: EP01_5-78.jpg → ep01578
# UNMATCHED: EP01_5-79.jpg → ep01579
# UNMATCHED: EP01_5-8.jpg → ep0158
# UNMATCHED: EP01_5-80.jpg → ep01580
# UNMATCHED: EP01_5-81.jpg → ep01581
# UNMATCHED: EP01_5-82.jpg → ep01582
# UNMATCHED: EP01_5-83.jpg → ep01583
# UNMATCHED: EP01_5-84.jpg → ep01584
# UNMATCHED: EP01_5-85.jpg → ep01585
# UNMATCHED: EP01_5-86.jpg → ep01586
# UNMATCHED: EP01_5-87.jpg → ep01587
# UNMATCHED: EP01_5-88.jpg → ep01588
# UNMATCHED: EP01_5-89.jpg → ep01589
# UNMATCHED: EP01_5-9.jpg → ep0159
# UNMATCHED: EP01_5-90.jpg → ep01590
# UNMATCHED: EP01_5-91.jpg → ep01591
# UNMATCHED: EP01_5-92.jpg → ep01592
# UNMATCHED: EP01_5-93.jpg → ep01593
# UNMATCHED: EP01_5-94.jpg → ep01594
# UNMATCHED: EP01_5-95.jpg → ep01595
# UNMATCHED: EP01_5-96.jpg → ep01596
# UNMATCHED: EP01_5-97.jpg → ep01597
# UNMATCHED: EP01_5-98.jpg → ep01598
# UNMATCHED: EP01_5-99.jpg → ep01599
# UNMATCHED: EP01_8-1.jpg → ep0181
# UNMATCHED: EP01_8-10.jpg → ep01810
# UNMATCHED: EP01_8-100.jpg → ep018100
# UNMATCHED: EP01_8-101.jpg → ep018101
# UNMATCHED: EP01_8-102.jpg → ep018102
# UNMATCHED: EP01_8-103.jpg → ep018103
# UNMATCHED: EP01_8-104.jpg → ep018104
# UNMATCHED: EP01_8-105.jpg → ep018105
# UNMATCHED: EP01_8-106.jpg → ep018106
# UNMATCHED: EP01_8-107.jpg → ep018107
# UNMATCHED: EP01_8-108.jpg → ep018108
# UNMATCHED: EP01_8-109.jpg → ep018109
# UNMATCHED: EP01_8-11.jpg → ep01811
# UNMATCHED: EP01_8-110.jpg → ep018110
# UNMATCHED: EP01_8-111.jpg → ep018111
# UNMATCHED: EP01_8-112.jpg → ep018112
# UNMATCHED: EP01_8-113.jpg → ep018113
# UNMATCHED: EP01_8-114.jpg → ep018114
# UNMATCHED: EP01_8-115.jpg → ep018115
# UNMATCHED: EP01_8-116.jpg → ep018116
# UNMATCHED: EP01_8-117.jpg → ep018117
# UNMATCHED: EP01_8-118.jpg → ep018118
# UNMATCHED: EP01_8-119.jpg → ep018119
# UNMATCHED: EP01_8-12.jpg → ep01812
# UNMATCHED: EP01_8-120.jpg → ep018120
# UNMATCHED: EP01_8-121.jpg → ep018121
# UNMATCHED: EP01_8-122.jpg → ep018122
# UNMATCHED: EP01_8-123.jpg → ep018123
# UNMATCHED: EP01_8-124.jpg → ep018124
# UNMATCHED: EP01_8-125.jpg → ep018125
# UNMATCHED: EP01_8-126.jpg → ep018126
# UNMATCHED: EP01_8-127.jpg → ep018127
# UNMATCHED: EP01_8-128.jpg → ep018128
# UNMATCHED: EP01_8-129.jpg → ep018129
# UNMATCHED: EP01_8-13.jpg → ep01813
# UNMATCHED: EP01_8-130.jpg → ep018130
# UNMATCHED: EP01_8-131.jpg → ep018131
# UNMATCHED: EP01_8-132.jpg → ep018132
# UNMATCHED: EP01_8-133.jpg → ep018133
# UNMATCHED: EP01_8-134.jpg → ep018134
# UNMATCHED: EP01_8-135.jpg → ep018135
# UNMATCHED: EP01_8-136.jpg → ep018136
# UNMATCHED: EP01_8-137.jpg → ep018137
# UNMATCHED: EP01_8-138.jpg → ep018138
# UNMATCHED: EP01_8-139.jpg → ep018139
# UNMATCHED: EP01_8-14.jpg → ep01814
# UNMATCHED: EP01_8-140.jpg → ep018140
# UNMATCHED: EP01_8-141.jpg → ep018141
# UNMATCHED: EP01_8-15.jpg → ep01815
# UNMATCHED: EP01_8-16.jpg → ep01816
# UNMATCHED: EP01_8-17.jpg → ep01817
# UNMATCHED: EP01_8-18.jpg → ep01818
# UNMATCHED: EP01_8-19.jpg → ep01819
# UNMATCHED: EP01_8-2.jpg → ep0182
# UNMATCHED: EP01_8-20.jpg → ep01820
# UNMATCHED: EP01_8-21.jpg → ep01821
# UNMATCHED: EP01_8-22.jpg → ep01822
# UNMATCHED: EP01_8-23.jpg → ep01823
# UNMATCHED: EP01_8-24.jpg → ep01824
# UNMATCHED: EP01_8-25.jpg → ep01825
# UNMATCHED: EP01_8-26.jpg → ep01826
# UNMATCHED: EP01_8-27.jpg → ep01827
# UNMATCHED: EP01_8-28.jpg → ep01828
# UNMATCHED: EP01_8-29.jpg → ep01829
# UNMATCHED: EP01_8-3.jpg → ep0183
# UNMATCHED: EP01_8-30.jpg → ep01830
# UNMATCHED: EP01_8-31.jpg → ep01831
# UNMATCHED: EP01_8-32.jpg → ep01832
# UNMATCHED: EP01_8-33.jpg → ep01833
# UNMATCHED: EP01_8-34.jpg → ep01834
# UNMATCHED: EP01_8-35.jpg → ep01835
# UNMATCHED: EP01_8-36.jpg → ep01836
# UNMATCHED: EP01_8-37.jpg → ep01837
# UNMATCHED: EP01_8-38.jpg → ep01838
# UNMATCHED: EP01_8-39.jpg → ep01839
# UNMATCHED: EP01_8-4.jpg → ep0184
# UNMATCHED: EP01_8-40.jpg → ep01840
# UNMATCHED: EP01_8-41.jpg → ep01841
# UNMATCHED: EP01_8-42.jpg → ep01842
# UNMATCHED: EP01_8-43.jpg → ep01843
# UNMATCHED: EP01_8-44.jpg → ep01844
# UNMATCHED: EP01_8-45.jpg → ep01845
# UNMATCHED: EP01_8-46.jpg → ep01846
# UNMATCHED: EP01_8-47.jpg → ep01847
# UNMATCHED: EP01_8-48.jpg → ep01848
# UNMATCHED: EP01_8-49.jpg → ep01849
# UNMATCHED: EP01_8-5.jpg → ep0185
# UNMATCHED: EP01_8-50.jpg → ep01850
# UNMATCHED: EP01_8-51.jpg → ep01851
# UNMATCHED: EP01_8-52.jpg → ep01852
# UNMATCHED: EP01_8-53.jpg → ep01853
# UNMATCHED: EP01_8-54.jpg → ep01854
# UNMATCHED: EP01_8-55.jpg → ep01855
# UNMATCHED: EP01_8-56.jpg → ep01856
# UNMATCHED: EP01_8-57.jpg → ep01857
# UNMATCHED: EP01_8-58.jpg → ep01858
# UNMATCHED: EP01_8-59.jpg → ep01859
# UNMATCHED: EP01_8-6.jpg → ep0186
# UNMATCHED: EP01_8-60.jpg → ep01860
# UNMATCHED: EP01_8-61.jpg → ep01861
# UNMATCHED: EP01_8-62.jpg → ep01862
# UNMATCHED: EP01_8-63.jpg → ep01863
# UNMATCHED: EP01_8-64.jpg → ep01864
# UNMATCHED: EP01_8-65.jpg → ep01865
# UNMATCHED: EP01_8-66.jpg → ep01866
# UNMATCHED: EP01_8-67.jpg → ep01867
# UNMATCHED: EP01_8-68.jpg → ep01868
# UNMATCHED: EP01_8-69.jpg → ep01869
# UNMATCHED: EP01_8-7.jpg → ep0187
# UNMATCHED: EP01_8-70.jpg → ep01870
# UNMATCHED: EP01_8-71.jpg → ep01871
# UNMATCHED: EP01_8-72.jpg → ep01872
# UNMATCHED: EP01_8-73.jpg → ep01873
# UNMATCHED: EP01_8-74.jpg → ep01874
# UNMATCHED: EP01_8-75.jpg → ep01875
# UNMATCHED: EP01_8-76.jpg → ep01876
# UNMATCHED: EP01_8-77.jpg → ep01877
# UNMATCHED: EP01_8-78.jpg → ep01878
# UNMATCHED: EP01_8-79.jpg → ep01879
# UNMATCHED: EP01_8-8.jpg → ep0188
# UNMATCHED: EP01_8-80.jpg → ep01880
# UNMATCHED: EP01_8-81.jpg → ep01881
# UNMATCHED: EP01_8-82.jpg → ep01882
# UNMATCHED: EP01_8-83.jpg → ep01883
# UNMATCHED: EP01_8-84.jpg → ep01884
# UNMATCHED: EP01_8-85.jpg → ep01885
# UNMATCHED: EP01_8-86.jpg → ep01886
# UNMATCHED: EP01_8-87.jpg → ep01887
# UNMATCHED: EP01_8-88.jpg → ep01888
# UNMATCHED: EP01_8-89.jpg → ep01889
# UNMATCHED: EP01_8-9.jpg → ep0189
# UNMATCHED: EP03_1-70.jpg → ep03170
# UNMATCHED: EP03_1-71.jpg → ep03171
# UNMATCHED: EP03_1-72.jpg → ep03172
# UNMATCHED: EP03_1-73.jpg → ep03173
# UNMATCHED: EP03_1-74.jpg → ep03174
# UNMATCHED: EP03_1-75.jpg → ep03175
# UNMATCHED: EP03_1-76.jpg → ep03176
# UNMATCHED: EP03_1-77.jpg → ep03177
# UNMATCHED: EP03_1-78.jpg → ep03178
# UNMATCHED: EP03_1-79.jpg → ep03179
# UNMATCHED: EP03_1-8.jpg → ep0318
# UNMATCHED: EP03_1-80.jpg → ep03180
# UNMATCHED: EP03_1-81.jpg → ep03181
# UNMATCHED: EP03_1-82.jpg → ep03182
# UNMATCHED: EP03_1-83.jpg → ep03183
# UNMATCHED: EP03_1-84.jpg → ep03184
# UNMATCHED: EP03_1-85.jpg → ep03185
# UNMATCHED: EP03_1-86.jpg → ep03186
# UNMATCHED: EP03_1-87.jpg → ep03187
# UNMATCHED: EP03_1-88.jpg → ep03188
# UNMATCHED: EP03_1-89.jpg → ep03189
# UNMATCHED: EP03_1-9.jpg → ep0319
# UNMATCHED: EP03_1-90.jpg → ep03190
# UNMATCHED: EP03_1-91.jpg → ep03191
# UNMATCHED: EP03_1-92.jpg → ep03192
# UNMATCHED: EP03_1-93.jpg → ep03193
# UNMATCHED: EP03_1-94.jpg → ep03194
# UNMATCHED: EP03_1-95.jpg → ep03195
# UNMATCHED: EP03_1-96.jpg → ep03196
# UNMATCHED: EP03_1-97.jpg → ep03197
# UNMATCHED: EP03_1-98.jpg → ep03198
# UNMATCHED: EP03_1-99.jpg → ep03199
# UNMATCHED: img1.jpg → img1
# UNMATCHED: img10.jpg → img10
# UNMATCHED: img100.jpg → img100
# UNMATCHED: img101.jpg → img101
# UNMATCHED: img102.jpg → img102
# UNMATCHED: img103.jpg → img103
# UNMATCHED: img104.jpg → img104
# UNMATCHED: img105.jpg → img105
# UNMATCHED: img106.jpg → img106
# UNMATCHED: img107.jpg → img107
# UNMATCHED: img108.jpg → img108
# UNMATCHED: img109.jpg → img109
# UNMATCHED: img11.jpg → img11
# UNMATCHED: img110.jpg → img110
# UNMATCHED: img111.jpg → img111
# UNMATCHED: img112.jpg → img112
# UNMATCHED: img113.jpg → img113
# UNMATCHED: img114.jpg → img114
# UNMATCHED: img115.jpg → img115
# UNMATCHED: img116.jpg → img116
# UNMATCHED: img117.jpg → img117
# UNMATCHED: img118.jpg → img118
# UNMATCHED: img119.jpg → img119
# UNMATCHED: img12.jpg → img12
# UNMATCHED: img120.jpg → img120
# UNMATCHED: img121.jpg → img121
# UNMATCHED: img122.jpg → img122
# UNMATCHED: img123.jpg → img123
# UNMATCHED: img124.jpg → img124
# UNMATCHED: img125.jpg → img125
# UNMATCHED: img126.jpg → img126
# UNMATCHED: img127.jpg → img127
# UNMATCHED: img128.jpg → img128
# UNMATCHED: img129.jpg → img129
# UNMATCHED: img13.jpg → img13
# UNMATCHED: img130.jpg → img130
# UNMATCHED: img131.jpg → img131
# UNMATCHED: img132.jpg → img132
# UNMATCHED: img133.jpg → img133
# UNMATCHED: img134.jpg → img134
# UNMATCHED: img135.jpg → img135
# UNMATCHED: img136.jpg → img136
# UNMATCHED: img137.jpg → img137
# UNMATCHED: img138.jpg → img138
# UNMATCHED: img139.jpg → img139
# UNMATCHED: img14.jpg → img14
# UNMATCHED: img140.jpg → img140
# UNMATCHED: img141.jpg → img141
# UNMATCHED: img142.jpg → img142
# UNMATCHED: img143.jpg → img143
# UNMATCHED: img144.jpg → img144
# UNMATCHED: img145.jpg → img145
# UNMATCHED: img146.jpg → img146
# UNMATCHED: img147.jpg → img147
# UNMATCHED: img148.jpg → img148
# UNMATCHED: img149.jpg → img149
# UNMATCHED: img15.jpg → img15
# UNMATCHED: img150.jpg → img150
# UNMATCHED: img151.jpg → img151
# UNMATCHED: img152.jpg → img152
# UNMATCHED: img153.jpg → img153
# UNMATCHED: img154.jpg → img154
# UNMATCHED: img155.jpg → img155
# UNMATCHED: img156.jpg → img156
# UNMATCHED: img157.jpg → img157
# UNMATCHED: img16.jpg → img16
# UNMATCHED: img17.jpg → img17
# UNMATCHED: img18.jpg → img18
# UNMATCHED: img19.jpg → img19
# UNMATCHED: img2.jpg → img2
# UNMATCHED: img20.jpg → img20
# UNMATCHED: img21.jpg → img21
# UNMATCHED: img22.jpg → img22
# UNMATCHED: img23.jpg → img23
# UNMATCHED: img24.jpg → img24
# UNMATCHED: img25.jpg → img25
# UNMATCHED: img26.jpg → img26
# UNMATCHED: img27.jpg → img27
# UNMATCHED: img28.jpg → img28
# UNMATCHED: img29.jpg → img29
# UNMATCHED: img3.jpg → img3
# UNMATCHED: img30.jpg → img30
# UNMATCHED: img31.jpg → img31
# UNMATCHED: img32.jpg → img32
# UNMATCHED: img33.jpg → img33
# UNMATCHED: img34.jpg → img34
# UNMATCHED: img35.jpg → img35
# UNMATCHED: img36.jpg → img36
# UNMATCHED: img37.jpg → img37
# UNMATCHED: img38.jpg → img38
# UNMATCHED: img39.jpg → img39
# UNMATCHED: img4.jpg → img4
# UNMATCHED: img40.jpg → img40
# UNMATCHED: img41.jpg → img41
# UNMATCHED: img42.jpg → img42
# UNMATCHED: img43.jpg → img43
# UNMATCHED: img44.jpg → img44
# UNMATCHED: img45.jpg → img45
# UNMATCHED: img46.jpg → img46
# UNMATCHED: img47.jpg → img47
# UNMATCHED: img48.jpg → img48
# UNMATCHED: img49.jpg → img49
# UNMATCHED: img5.jpg → img5
# UNMATCHED: img50.jpg → img50
# UNMATCHED: img51.jpg → img51
# UNMATCHED: img52.jpg → img52
# UNMATCHED: img53.jpg → img53
# UNMATCHED: img54.jpg → img54
# UNMATCHED: img55.jpg → img55
# UNMATCHED: img56.jpg → img56
# UNMATCHED: img57.jpg → img57
# UNMATCHED: img58.jpg → img58
# UNMATCHED: img59.jpg → img59
# UNMATCHED: img6.jpg → img6
# UNMATCHED: img60.jpg → img60
# UNMATCHED: img61.jpg → img61
# UNMATCHED: img62.jpg → img62
# UNMATCHED: img63.jpg → img63
# UNMATCHED: img64.jpg → img64
# UNMATCHED: img65.jpg → img65
# UNMATCHED: img66.jpg → img66
# UNMATCHED: img67.jpg → img67
# UNMATCHED: img68.jpg → img68
# UNMATCHED: img69.jpg → img69
# UNMATCHED: img7.jpg → img7
# UNMATCHED: img70.jpg → img70
# UNMATCHED: img71.jpg → img71
# UNMATCHED: img72.jpg → img72
# UNMATCHED: img73.jpg → img73
# UNMATCHED: img74.jpg → img74
# UNMATCHED: img75.jpg → img75
# UNMATCHED: img76.jpg → img76
# UNMATCHED: img77.jpg → img77
# UNMATCHED: img78.jpg → img78
# UNMATCHED: img79.jpg → img79
# UNMATCHED: img8.jpg → img8
# UNMATCHED: img80.jpg → img80
# UNMATCHED: img81.jpg → img81
# UNMATCHED: img82.jpg → img82
# UNMATCHED: img83.jpg → img83
# UNMATCHED: img84.jpg → img84
# UNMATCHED: img85.jpg → img85
# UNMATCHED: img86.jpg → img86
# UNMATCHED: img87.jpg → img87
# UNMATCHED: img88.jpg → img88
# UNMATCHED: img89.jpg → img89
# UNMATCHED: img9.jpg → img9
# UNMATCHED: img90.jpg → img90
# UNMATCHED: img91.jpg → img91
# UNMATCHED: img92.jpg → img92
# UNMATCHED: img93.jpg → img93
# UNMATCHED: img94.jpg → img94
# UNMATCHED: img95.jpg → img95
# UNMATCHED: img96.jpg → img96
# UNMATCHED: img97.jpg → img97
# UNMATCHED: img98.jpg → img98
# UNMATCHED: img99.jpg → img99
# UNMATCHED: EP05_2-1.jpg → ep0521
# UNMATCHED: EP05_2-10.jpg → ep05210
# UNMATCHED: EP05_2-100.jpg → ep052100
# UNMATCHED: EP05_2-101.jpg → ep052101
# UNMATCHED: EP05_2-102.jpg → ep052102
# UNMATCHED: EP05_2-103.jpg → ep052103
# UNMATCHED: EP05_2-104.jpg → ep052104
# UNMATCHED: EP05_2-105.jpg → ep052105
# UNMATCHED: EP05_2-106.jpg → ep052106
# UNMATCHED: EP05_2-107.jpg → ep052107
# UNMATCHED: EP05_2-108.jpg → ep052108
# UNMATCHED: EP05_2-109.jpg → ep052109
# UNMATCHED: EP05_2-11.jpg → ep05211
# UNMATCHED: EP05_2-110.jpg → ep052110
# UNMATCHED: EP05_2-111.jpg → ep052111
# UNMATCHED: EP05_2-112.jpg → ep052112
# UNMATCHED: EP05_2-113.jpg → ep052113
# UNMATCHED: EP05_2-114.jpg → ep052114
# UNMATCHED: EP05_2-115.jpg → ep052115
# UNMATCHED: EP05_2-116.jpg → ep052116
# UNMATCHED: EP05_2-117.jpg → ep052117
# UNMATCHED: EP05_2-118.jpg → ep052118
# UNMATCHED: EP05_2-119.jpg → ep052119
# UNMATCHED: EP05_2-12.jpg → ep05212
# UNMATCHED: EP05_2-120.jpg → ep052120
# UNMATCHED: EP05_2-121.jpg → ep052121
# UNMATCHED: EP05_2-122.jpg → ep052122
# UNMATCHED: EP05_2-123.jpg → ep052123
# UNMATCHED: EP05_2-124.jpg → ep052124
# UNMATCHED: EP05_2-125.jpg → ep052125
# UNMATCHED: EP05_2-126.jpg → ep052126
# UNMATCHED: EP05_2-127.jpg → ep052127
# UNMATCHED: EP05_2-128.jpg → ep052128
# UNMATCHED: EP05_2-129.jpg → ep052129
# UNMATCHED: EP05_2-13.jpg → ep05213
# UNMATCHED: EP05_2-130.jpg → ep052130
# UNMATCHED: EP05_2-131.jpg → ep052131
# UNMATCHED: EP05_2-132.jpg → ep052132
# UNMATCHED: EP05_2-133.jpg → ep052133
# UNMATCHED: EP05_2-134.jpg → ep052134
# UNMATCHED: EP05_2-135.jpg → ep052135
# UNMATCHED: EP05_2-136.jpg → ep052136
# UNMATCHED: EP05_2-137.jpg → ep052137
# UNMATCHED: EP05_2-138.jpg → ep052138
# UNMATCHED: EP05_2-139.jpg → ep052139
# UNMATCHED: EP05_2-14.jpg → ep05214
# UNMATCHED: EP05_2-140.jpg → ep052140
# UNMATCHED: EP05_2-141.jpg → ep052141
# UNMATCHED: EP05_2-142.jpg → ep052142
# UNMATCHED: EP05_2-143.jpg → ep052143
# UNMATCHED: EP05_2-144.jpg → ep052144
# UNMATCHED: EP05_2-145.jpg → ep052145
# UNMATCHED: EP05_2-146.jpg → ep052146
# UNMATCHED: EP05_2-147.jpg → ep052147
# UNMATCHED: EP05_2-148.jpg → ep052148
# UNMATCHED: EP05_2-15.jpg → ep05215
# UNMATCHED: EP05_2-16.jpg → ep05216
# UNMATCHED: EP05_2-17.jpg → ep05217
# UNMATCHED: EP05_2-18.jpg → ep05218
# UNMATCHED: EP05_2-19.jpg → ep05219
# UNMATCHED: EP05_2-2.jpg → ep0522
# UNMATCHED: EP05_2-20.jpg → ep05220
# UNMATCHED: EP05_2-21.jpg → ep05221
# UNMATCHED: EP05_2-22.jpg → ep05222
# UNMATCHED: EP05_2-23.jpg → ep05223
# UNMATCHED: EP05_2-24.jpg → ep05224
# UNMATCHED: EP05_2-25.jpg → ep05225
# UNMATCHED: EP05_2-26.jpg → ep05226
# UNMATCHED: EP05_2-27.jpg → ep05227
# UNMATCHED: EP05_2-28.jpg → ep05228
# UNMATCHED: EP05_2-29.jpg → ep05229
# UNMATCHED: EP05_2-3.jpg → ep0523
# UNMATCHED: EP05_2-30.jpg → ep05230
# UNMATCHED: EP05_2-31.jpg → ep05231
# UNMATCHED: EP05_2-32.jpg → ep05232
# UNMATCHED: EP05_2-33.jpg → ep05233
# UNMATCHED: EP05_2-34.jpg → ep05234
# UNMATCHED: EP05_2-35.jpg → ep05235
# UNMATCHED: EP05_2-36.jpg → ep05236
# UNMATCHED: EP05_2-37.jpg → ep05237
# UNMATCHED: EP05_2-38.jpg → ep05238
# UNMATCHED: EP05_2-39.jpg → ep05239
# UNMATCHED: EP05_2-4.jpg → ep0524
# UNMATCHED: EP05_2-40.jpg → ep05240
# UNMATCHED: EP05_2-41.jpg → ep05241
# UNMATCHED: EP05_2-42.jpg → ep05242
# UNMATCHED: EP05_2-43.jpg → ep05243
# UNMATCHED: EP05_2-44.jpg → ep05244
# UNMATCHED: EP05_2-45.jpg → ep05245
# UNMATCHED: EP05_2-46.jpg → ep05246
# UNMATCHED: EP05_2-47.jpg → ep05247
# UNMATCHED: EP05_2-48.jpg → ep05248
# UNMATCHED: EP05_2-49.jpg → ep05249
# UNMATCHED: EP05_2-5.jpg → ep0525
# UNMATCHED: EP05_2-50.jpg → ep05250
# UNMATCHED: EP05_2-51.jpg → ep05251
# UNMATCHED: EP05_2-52.jpg → ep05252
# UNMATCHED: EP05_2-53.jpg → ep05253
# UNMATCHED: EP05_2-54.jpg → ep05254
# UNMATCHED: EP05_2-55.jpg → ep05255
# UNMATCHED: EP05_2-56.jpg → ep05256
# UNMATCHED: EP05_2-57.jpg → ep05257
# UNMATCHED: EP05_2-58.jpg → ep05258
# UNMATCHED: EP05_2-59.jpg → ep05259
# UNMATCHED: EP05_2-6.jpg → ep0526
# UNMATCHED: EP05_2-60.jpg → ep05260
# UNMATCHED: EP05_2-61.jpg → ep05261
# UNMATCHED: EP05_2-62.jpg → ep05262
# UNMATCHED: EP05_2-63.jpg → ep05263
# UNMATCHED: EP05_2-64.jpg → ep05264
# UNMATCHED: EP05_2-65.jpg → ep05265
# UNMATCHED: EP05_2-66.jpg → ep05266
# UNMATCHED: EP05_2-67.jpg → ep05267
# UNMATCHED: EP05_2-68.jpg → ep05268
# UNMATCHED: EP05_2-69.jpg → ep05269
# UNMATCHED: EP05_2-7.jpg → ep0527
# UNMATCHED: EP05_2-70.jpg → ep05270
# UNMATCHED: EP05_2-71.jpg → ep05271
# UNMATCHED: EP05_2-72.jpg → ep05272
# UNMATCHED: EP05_2-73.jpg → ep05273
# UNMATCHED: EP05_2-74.jpg → ep05274
# UNMATCHED: EP05_2-75.jpg → ep05275
# UNMATCHED: EP05_2-76.jpg → ep05276
# UNMATCHED: EP05_2-77.jpg → ep05277
# UNMATCHED: EP05_2-78.jpg → ep05278
# UNMATCHED: EP05_2-79.jpg → ep05279
# UNMATCHED: EP05_2-8.jpg → ep0528
# UNMATCHED: EP05_2-80.jpg → ep05280
# UNMATCHED: EP05_2-81.jpg → ep05281
# UNMATCHED: EP05_2-82.jpg → ep05282
# UNMATCHED: EP05_2-83.jpg → ep05283
# UNMATCHED: EP05_2-84.jpg → ep05284
# UNMATCHED: EP05_2-85.jpg → ep05285
# UNMATCHED: EP05_2-86.jpg → ep05286
# UNMATCHED: EP05_2-87.jpg → ep05287
# UNMATCHED: EP05_2-88.jpg → ep05288
# UNMATCHED: EP05_2-89.jpg → ep05289
# UNMATCHED: EP05_2-9.jpg → ep0529
# UNMATCHED: EP05_2-90.jpg → ep05290
# UNMATCHED: EP05_2-91.jpg → ep05291
# UNMATCHED: EP05_2-92.jpg → ep05292
# UNMATCHED: EP05_2-93.jpg → ep05293
# UNMATCHED: EP05_2-94.jpg → ep05294
# UNMATCHED: EP05_2-95.jpg → ep05295
# UNMATCHED: EP05_2-96.jpg → ep05296
# UNMATCHED: EP05_2-97.jpg → ep05297
# UNMATCHED: EP05_2-98.jpg → ep05298
# UNMATCHED: EP05_2-99.jpg → ep05299
# UNMATCHED: EP05_4-1.jpg → ep0541
# UNMATCHED: EP05_4-10.jpg → ep05410
# UNMATCHED: EP05_4-100.jpg → ep054100
# UNMATCHED: EP05_4-101.jpg → ep054101
# UNMATCHED: EP05_4-102.jpg → ep054102
# UNMATCHED: EP05_4-103.jpg → ep054103
# UNMATCHED: EP05_4-104.jpg → ep054104
# UNMATCHED: EP05_4-105.jpg → ep054105
# UNMATCHED: EP05_4-106.jpg → ep054106
# UNMATCHED: EP05_4-107.jpg → ep054107
# UNMATCHED: EP05_4-108.jpg → ep054108
# UNMATCHED: EP05_4-109.jpg → ep054109
# UNMATCHED: EP05_4-11.jpg → ep05411
# UNMATCHED: EP05_4-110.jpg → ep054110
# UNMATCHED: EP05_4-111.jpg → ep054111
# UNMATCHED: EP05_4-112.jpg → ep054112
# UNMATCHED: EP05_4-113.jpg → ep054113
# UNMATCHED: EP05_4-114.jpg → ep054114
# UNMATCHED: EP05_4-115.jpg → ep054115
# UNMATCHED: EP05_4-116.jpg → ep054116
# UNMATCHED: EP05_4-117.jpg → ep054117
# UNMATCHED: EP05_4-118.jpg → ep054118
# UNMATCHED: EP05_4-119.jpg → ep054119
# UNMATCHED: EP05_4-12.jpg → ep05412
# UNMATCHED: EP05_4-120.jpg → ep054120
# UNMATCHED: EP05_4-121.jpg → ep054121
# UNMATCHED: EP05_4-122.jpg → ep054122
# UNMATCHED: EP05_4-123.jpg → ep054123
# UNMATCHED: EP05_4-124.jpg → ep054124
# UNMATCHED: EP05_4-125.jpg → ep054125
# UNMATCHED: EP05_4-126.jpg → ep054126
# UNMATCHED: EP05_4-127.jpg → ep054127
# UNMATCHED: EP05_4-128.jpg → ep054128
# UNMATCHED: EP05_4-129.jpg → ep054129
# UNMATCHED: EP05_4-13.jpg → ep05413
# UNMATCHED: EP05_4-130.jpg → ep054130
# UNMATCHED: EP05_4-131.jpg → ep054131
# UNMATCHED: EP05_4-132.jpg → ep054132
# UNMATCHED: EP05_4-133.jpg → ep054133
# UNMATCHED: EP05_4-134.jpg → ep054134
# UNMATCHED: EP05_4-135.jpg → ep054135
# UNMATCHED: EP05_4-136.jpg → ep054136
# UNMATCHED: EP05_4-137.jpg → ep054137
# UNMATCHED: EP05_4-138.jpg → ep054138
# UNMATCHED: EP05_4-139.jpg → ep054139
# UNMATCHED: EP05_4-14.jpg → ep05414
# UNMATCHED: EP05_4-140.jpg → ep054140
# UNMATCHED: EP05_4-141.jpg → ep054141
# UNMATCHED: EP05_4-15.jpg → ep05415
# ...
# UNMATCHED: EP12_1-213.jpg → ep121213
# UNMATCHED: EP12_1-214.jpg → ep121214
# UNMATCHED: EP12_1-215.jpg → ep121215
# UNMATCHED: EP12_1-216.jpg → ep121216
# UNMATCHED: EP12_2-001.jpg → ep122001
# UNMATCHED: EP12_2-002.jpg → ep122002
# UNMATCHED: EP12_2-003.jpg → ep122003
# UNMATCHED: EP12_2-004.jpg → ep122004
# UNMATCHED: EP12_2-005.jpg → ep122005
# UNMATCHED: EP12_2-006.jpg → ep122006
# UNMATCHED: EP12_2-007.jpg → ep122007
# UNMATCHED: EP12_4-155.jpg → ep124155
# UNMATCHED: EP12_4-156.jpg → ep124156
# UNMATCHED: EP12_4-157.jpg → ep124157
# UNMATCHED: EP12_4-158.jpg → ep124158
# UNMATCHED: EP12_4-159.jpg → ep124159
# UNMATCHED: EP12_4-160.jpg → ep124160
# UNMATCHED: EP12_4-161.jpg → ep124161

# %%
def LearNet_Modelbuild(height=112, width=112, channels=3, classes=8):
    im = Input(shape=(height, width, channels))
    Conv_S = Conv2D(16, (3, 3), activation='relu', padding='same', strides=2, name='Conv_S')(im)

    Conv_1_1 = Conv2D(16, (1, 1), activation='relu', padding='same', strides=2, name='Conv_1_1')(Conv_S)
    Conv_1_2 = Conv2D(32, (3, 3), activation='relu', padding='same', strides=2, name='Conv_1_2')(Conv_1_1)
    Conv_1_3 = Conv2D(64, (5, 5), activation='relu', padding='same', strides=2, name='Conv_1_3')(Conv_1_2)

    Conv_2_1 = Conv2D(16, (1, 1), activation='relu', padding='same', strides=2, name='Conv_2_1')(Conv_S)
    add_2_1 = add([Conv_1_1, Conv_2_1])
    batch_r11 = BatchNormalization()(add_2_1)
    Conv_2_2 = Conv2D(32, (3, 3), activation='relu', padding='same', strides=2, name='Conv_2_2')(batch_r11)
    add_2_2 = add([Conv_1_2, Conv_2_2])
    batch_r12 = BatchNormalization()(add_2_2)
    Conv_x_2 = Conv2D(64, (5, 5), activation='relu', padding='same', strides=2, name='Conv_x_2')(batch_r12)

    Conv_3_1 = Conv2D(16, (1, 1), activation='relu', padding='same', strides=2, name='Conv_3_1')(Conv_S)
    Conv_3_2 = Conv2D(32, (3, 3), activation='relu', padding='same', strides=2, name='Conv_3_2')(Conv_3_1)
    Conv_3_3 = Conv2D(64, (5, 5), activation='relu', padding='same', strides=2, name='Conv_3_3')(Conv_3_2)

    Conv_4_1 = Conv2D(16, (1, 1), activation='relu', padding='same', strides=2, name='Conv_4_1')(Conv_S)
    add_4_1 = add([Conv_3_1, Conv_4_1])
    batch_r13 = BatchNormalization()(add_4_1)
    Conv_4_2 = Conv2D(32, (3, 3), activation='relu', padding='same', strides=2, name='Conv_4_2')(batch_r13)
    add_4_2 = add([Conv_3_2, Conv_4_2])
    batch_r14 = BatchNormalization()(add_4_2)
    Conv_x_4 = Conv2D(64, (5, 5), activation='relu', padding='same', strides=2, name='Conv_x_4')(batch_r14)

    concta1 = concatenate([Conv_1_3, Conv_x_2, Conv_3_3, Conv_x_4])
    batch_X = BatchNormalization()(concta1)

    Conv_5_1 = Conv2D(256, (3, 3), activation='relu', padding='same', strides=2, name='Conv_5_1')(batch_X)

    F1 = Flatten()(Conv_5_1)
    FC1 = Dense(256, activation='relu')(F1)
    drop = Dropout(0.5)(FC1)

    out = Dense(classes, activation='softmax')(drop)

    model = Model(inputs=[im], outputs=out)
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model = LearNet_Modelbuild(112, 112, 3, num_classes)
    checkpoint = ModelCheckpoint(
        'lear_net_best.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1
    )
    early_stop = EarlyStopping(
        monitor='val_loss', patience=8, restore_best_weights=True, verbose=1
    )
